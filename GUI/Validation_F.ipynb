# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Protocol 1

# %% [markdown]
# ## Protocol 1 Option 1

# %%
# Dati combinati
data_p1_o1_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle"
    ],
    "RR (breaths/min)": [
        12, 12, 12, 11, 11, 12, 10, 13, 12, 11,
        11, 12, 11, 12, 12, 14, 10, 12, 11, 12,
        12, 14, 10, 10, 14, 11, 12, 11, 11, 12
    ],
    "Inspiration Time (s)": [
        2.4, 2.32, 2.51, 2.64, 1.78, 2.66, 2.52, 1.86, 2.45, 2.62,
        3.04, 2.7, 2.74, 2.33, 2.29, 2.26, 2.9, 2.44, 2.17, 2.24,
        2.54, 1.98, 3.62, 2.54, 2.08, 2.63, 2.44, 2.54, 2.28, 2.56
    ],
    "Expiration Time (s)": [
        2.42, 2.57, 2.17, 2.42, 3.24, 2.02, 3.41, 2.6, 2.36, 2.6,
        2.12, 2.28, 2.58, 2.38, 2.56, 1.92, 2.98, 2.52, 2.92, 2.47,
        2.44, 2.04, 2.11, 2.92, 2.17, 2.4, 2.51, 2.5, 2.84, 2.3
    ]
}

# Creazione del DataFrame
df_p1_o1_f = pd.DataFrame(data_p1_o1_f)

# Ricalcola I/E Ratio
df_p1_o1_f['I/E Ratio'] = round((df_p1_o1_f['Inspiration Time (s)'] / df_p1_o1_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame
df_p1_o1_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.40                 2.42
# 1    2th cycle                12                  2.32                 2.57
# 2    3th cycle                12                  2.51                 2.17
# 3    4th cycle                11                  2.64                 2.42
# 4    5th cycle                11                  1.78                 3.24
# 5    6th cycle                12                  2.66                 2.02
# 6    7th cycle                10                  2.52                 3.41
# 7    8th cycle                13                  1.86                 2.60
# 8    9th cycle                12                  2.45                 2.36
# 9   10th cycle                11                  2.62                 2.60
# 10   1th cycle                11                  3.04                 2.12
# ...

# %% [markdown]
# ## Protocollo 1 - Opzione 2

# %%
# Dati manualmente estratti dalle immagini per Protocollo 1 Opzione 2
data_p1_o2_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle"
    ],
    "RR (breaths/min)": [
        12, 12, 11, 11, 12, 12, 11, 13, 12, 11,
        12, 12, 13, 11, 13, 12, 11, 11, 11, 12,
        13, 11, 13, 11, 12, 13, 13, 12, 10, 11,
        11
    ],
    "Inspiration Time (s)": [
        2.71, 2.32, 2.52, 2.34, 2.53, 2.34, 2.67, 2.19, 2.59, 2.65,
        2.45, 2.54, 2.36, 3.04, 2.5, 2.46, 3.02, 2.76, 2.36, 2.5,
        2.28, 2.39, 2.4, 3.04, 2.5, 2.15, 1.8, 2.27, 2.71, 2.34,
        2.26
    ],
    "Expiration Time (s)": [
        2.06, 2.42, 2.57, 2.94, 2.15, 2.5, 2.34, 2.31, 2.41, 2.62,
        2.27, 2.33, 2.23, 2.24, 1.89, 2.54, 2.26, 2.3, 2.5, 2.27,
        2.06, 2.76, 2.19, 2.33, 2.39, 2.29, 2.72, 2.4, 2.97, 2.73,
        3.1
    ]
}

# Creazione del DataFrame
df_p1_o2_f = pd.DataFrame(data_p1_o2_f)

# Ricalcola I/E Ratio
df_p1_o2_f['I/E Ratio'] = round((df_p1_o2_f['Inspiration Time (s)'] / df_p1_o2_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p1_o2_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.71                 2.06
# 1    2th cycle                12                  2.32                 2.42
# 2    3th cycle                11                  2.52                 2.57
# 3    4th cycle                11                  2.34                 2.94
# 4    5th cycle                12                  2.53                 2.15
# 5    6th cycle                12                  2.34                 2.50
# 6    7th cycle                11                  2.67                 2.34
# 7    8th cycle                13                  2.19                 2.31
# 8    9th cycle                12                  2.59                 2.41
# 9   10th cycle                11                  2.65                 2.62
# 10   1th cycle                12                  2.45                 2.27
# ...

# %% [markdown]
# ## Protocollo 1 - Opzione 3

# %%
# Dati manualmente estratti dalle nuove immagini per Protocollo 1 Opzione 3
data_p1_o3_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle"
    ],
    "RR (breaths/min)": [
        12, 11, 12, 12, 12, 11, 11, 13, 11, 12,
        12, 12, 12, 12, 11, 11, 13, 12, 12, 11,
        12, 12, 12, 12, 11, 12, 13, 11, 11
    ],
    "Inspiration Time (s)": [
        2.08, 2.82, 1.99, 1.79, 1.9, 2.34, 2.26, 2.28, 2.17, 1.99,
        2.35, 2.14, 2.2, 2.1, 2.2, 2.29, 1.84, 2.52, 2.28, 2.7,
        2.35, 1.98, 2.28, 2.29, 2.35, 2.18, 2.14, 2.28, 2.46
    ],
    "Expiration Time (s)": [
        2.88, 2.26, 2.92, 2.88, 2.92, 3.05, 2.9, 2.13, 2.98, 2.7,
        2.61, 2.8, 2.51, 2.75, 3.04, 2.72, 2.74, 2.42, 2.7, 2.66,
        2.5, 2.74, 2.7, 2.52, 2.72, 2.46, 2.35, 2.96, 2.69
    ]
}

# Creazione del DataFrame
df_p1_o3_f = pd.DataFrame(data_p1_o3_f)

# Ricalcola I/E Ratio
df_p1_o3_f['I/E Ratio'] = round((df_p1_o3_f['Inspiration Time (s)'] / df_p1_o3_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p1_o3_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.08                 2.88
# 1    2th cycle                11                  2.82                 2.26
# 2    3th cycle                12                  1.99                 2.92
# 3    4th cycle                12                  1.79                 2.88
# 4    5th cycle                12                  1.90                 2.92
# 5    6th cycle                11                  2.34                 3.05
# 6    7th cycle                11                  2.26                 2.90
# 7    8th cycle                13                  2.28                 2.13
# 8    9th cycle                11                  2.17                 2.98
# 9   10th cycle                12                  1.99                 2.70
# 10   1th cycle                12                  2.35                 2.61
# ...

# %% [markdown]
# ## Protocollo 1 - Opzione 4

# %%
# Dati manualmente estratti dalle nuove immagini per Protocollo 1 Opzione 4
data_p1_o4_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle"
    ],
    "RR (breaths/min)": [
        12, 11, 12, 12, 13, 10, 15, 11, 12, 12,
        10,
        13, 11, 12, 13, 11, 13, 15, 9, 12, 12,
        13,
        13, 12, 13, 11, 12, 11, 12, 10, 13, 13
    ],
    "Inspiration Time (s)": [
        2.02, 2.88, 2.78, 2.42, 2.27, 2.27, 1.92, 2.6, 2.66, 2.24,
        3.06,
        2.04, 1.94, 2.66, 3.0, 3.06, 2.82, 1.66, 3.02, 2.37, 2.87,
        2.44,
        2.5, 2.04, 2.17, 2.8, 2.92, 3.06, 2.56, 3.22, 2.5, 2.4
    ],
    "Expiration Time (s)": [
        2.96, 2.25, 2.0, 2.5, 2.18, 3.24, 2.02, 2.44, 2.02, 2.44,
        2.44,
        2.53, 3.12, 2.14, 1.56, 2.28, 1.79, 2.26, 3.24, 2.43, 2.13,
        2.03,
        2.1, 2.8, 2.38, 2.38, 2.08, 2.09, 2.16, 2.37, 1.96, 2.09
    ]
}

# Creazione del DataFrame
df_p1_o4_f = pd.DataFrame(data_p1_o4_f)

# Ricalcola I/E Ratio
df_p1_o4_f['I/E Ratio'] = round((df_p1_o4_f['Inspiration Time (s)'] / df_p1_o4_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p1_o4_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.02                 2.96
# 1    2th cycle                11                  2.88                 2.25
# 2    3th cycle                12                  2.78                 2.00
# 3    4th cycle                12                  2.42                 2.50
# 4    5th cycle                13                  2.27                 2.18
# 5    6th cycle                10                  2.27                 3.24
# 6    7th cycle                15                  1.92                 2.02
# 7    8th cycle                11                  2.60                 2.44
# 8    9th cycle                12                  2.66                 2.02
# 9   10th cycle                12                  2.24                 2.44
# 10  11th cycle                10                  3.06                 2.44
# ...

# %% [markdown]
# # Protocol 1 statistical analysis

# %%
# Definisci il target RR
target_rr = 12

# Lista dei dataframe delle varie opzioni
dfs = [df_p1_o1_f, df_p1_o2_f, df_p1_o3_f, df_p1_o4_f]
option_names = ['Option 1', 'Option 2', 'Option 3', 'Option 4']

# Funzione per eseguire l'analisi statistica e generare il grafico per ogni opzione
def analyze_option(df, option_name):
    df['Error'] = df['RR (breaths/min)'] - target_rr

    # Calcolo delle metriche statistiche
    mse = mean_squared_error(df['RR (breaths/min)'], [target_rr] * len(df))
    mae = mean_absolute_error(df['RR (breaths/min)'], [target_rr] * len(df))
    rmse = np.sqrt(mse)
    std_dev = np.std(df['RR (breaths/min)'])

    # Stampa delle metriche
    print(f'{option_name}:')
    print(f'MSE: {mse}')
    print(f'MAE: {mae}')
    print(f'RMSE: {rmse}')
    print(f'Standard Deviation: {std_dev}')
    print('\n')

    # Genera il grafico
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
    plt.axhline(y=target_rr, color='r', linestyle='--', label='Target RR = 12 breaths/min')
    plt.xlabel('Index')
    plt.ylabel('RR (breaths/min)')
    plt.title(f'Respiratory Rate Analysis - {option_name}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Esegui l'analisi per ogni opzione
for df, option_name in zip(dfs, option_names):
    analyze_option(df, option_name)

# Combinazione dei dati per analisi complessiva
df_combined = pd.concat(dfs, ignore_index=True)
df_combined['Error'] = df_combined['RR (breaths/min)'] - target_rr

# Calcolo delle metriche statistiche complessive
mse_total = mean_squared_error(df_combined['RR (breaths/min)'], [target_rr] * len(df_combined))
mae_total = mean_absolute_error(df_combined['RR (breaths/min)'], [target_rr] * len(df_combined))
rmse_total = np.sqrt(mse_total)
std_dev_total = np.std(df_combined['RR (breaths/min)'])

# Stampa delle metriche complessive
print('Overall Analysis:')
print(f'MSE: {mse_total}')
print(f'MAE: {mae_total}')
print(f'RMSE: {rmse_total}')
print(f'Standard Deviation: {std_dev_total}')

# Genera il grafico complessivo
plt.figure(figsize=(12, 6))
plt.plot(df_combined.index, df_combined['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
plt.axhline(y=target_rr, color='r', linestyle='--', label='Target RR = 12 breaths/min')
plt.xlabel('Index')
plt.ylabel('RR (breaths/min)')
plt.title('Respiratory Rate Analysis - Overall')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Option 1:
# MSE: 1.2666666666666666
# MAE: 0.8
# RMSE: 1.1254628677422756
# Standard Deviation: 1.07496769977314
# Option 2:
# MSE: 0.7419354838709677
# MAE: 0.6774193548387096
# RMSE: 0.861356769214109
# Standard Deviation: 0.83123217591775
# Option 3:
# MSE: 0.4482758620689655
# MAE: 0.4482758620689655
# RMSE: 0.6695340634119862
# Standard Deviation: 0.6245093198715459
# Option 4:
# MSE: 1.6875
# MAE: 0.9375
# RMSE: 1.299038105676658
# Standard Deviation: 1.299038105676658
# Overall Analysis:
# MSE: 1.0491803278688525
# MAE: 0.7213114754098361
# RMSE: 1.0242950394631678
# Standard Deviation: 1.0052268666725175

# %% [markdown]
# ## Protocollo 2

# %% [markdown]
# ## Protocollo 2 - Opzione 1

# %%
# Dati manualmente estratti dalle nuove immagini per Protocollo 2 Opzione 1
data_p2_o1_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle"
    ],
    "RR (breaths/min)": [
        12, 15, 15, 14, 15, 15, 14, 15, 15, 14,
        15, 15, 15,
        13, 14, 7, 16, 15, 15, 7, 16, 13, 14,
        16,
        13, 15, 15, 16, 17, 15, 12, 15, 13, 14,
        14, 14, 17
    ],
    "Inspiration Time (s)": [
        2.24, 1.93, 1.91, 1.82, 1.98, 1.8, 1.96, 2.08, 1.99, 1.89,
        1.9, 1.78, 2.02,
        2.34, 1.72, 1.78, 1.7, 2.11, 1.64, 6.65, 2.0, 2.28, 1.82,
        1.74,
        2.2, 2.48, 1.49, 1.54, 1.74, 1.88, 2.13, 1.96, 2.12, 1.71,
        2.02, 2.21, 1.76
    ],
    "Expiration Time (s)": [
        2.4, 1.9, 1.93, 2.37, 1.92, 2.02, 2.2, 1.9, 2.0, 2.18,
        2.0, 2.1, 1.98,
        2.04, 2.4, 6.15, 2.03, 1.76, 2.22, 1.56, 1.69, 2.21, 2.47,
        2.0,
        2.1, 1.4, 2.47, 2.0, 1.63, 2.08, 2.5, 1.82, 2.22, 2.32,
        2.03, 1.93, 1.76
    ]
}

# Creazione del DataFrame
df_p2_o1_f = pd.DataFrame(data_p2_o1_f)

# Ricalcola I/E Ratio
df_p2_o1_f['I/E Ratio'] = round((df_p2_o1_f['Inspiration Time (s)'] / df_p2_o1_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p2_o1_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.24                 2.40
# 1    2th cycle                15                  1.93                 1.90
# 2    3th cycle                15                  1.91                 1.93
# 3    4th cycle                14                  1.82                 2.37
# 4    5th cycle                15                  1.98                 1.92
# 5    6th cycle                15                  1.80                 2.02
# 6    7th cycle                14                  1.96                 2.20
# 7    8th cycle                15                  2.08                 1.90
# 8    9th cycle                15                  1.99                 2.00
# 9   10th cycle                14                  1.89                 2.18
# 10  11th cycle                15                  1.90                 2.00
# ...

# %% [markdown]
# ## Protocollo 2 - Opzione 2

# %%
# Dati per Protocollo 2 - Opzione 2
data_p2_o2_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle", "14th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle", "14th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle", "14th cycle"
    ],
    "RR (breaths/min)": [
        13, 15, 14, 15, 14, 15, 14, 15, 15, 15,
        15, 15, 12, 13,
        13, 14, 16, 14, 15, 15, 15, 14, 14, 15,
        15, 15, 14, 14,
        15, 14, 14, 14, 15, 16, 14, 14, 14, 15,
        15, 15, 15, 13
    ],
    "Inspiration Time (s)": [
        2.15, 2.11, 1.98, 1.78, 1.94, 1.78, 2.1, 1.82, 1.8, 1.85,
        1.94, 1.78, 2.44, 1.98,
        2.52, 2.26, 2.1, 2.0, 1.78, 1.94, 1.83, 2.26, 2.13, 1.96,
        2.02, 1.74, 2.0, 2.04,
        2.12, 2.24, 2.15, 2.14, 2.15, 1.86, 2.15, 1.96, 2.12, 2.15,
        1.88, 1.86, 1.87, 1.89
    ],
    "Expiration Time (s)": [
        2.31, 1.78, 2.1, 2.08, 2.15, 2.12, 1.94, 1.94, 2.06, 2.07,
        1.86, 2.0, 2.22, 2.54,
        1.78, 1.99, 1.5, 2.04, 2.1, 2.05, 2.06, 1.89, 1.9, 1.92,
        1.9, 2.05, 2.02, 2.1,
        1.64, 1.88, 1.92, 2.03, 1.72, 1.85, 2.05, 2.07, 1.91, 2.22,
        1.88, 1.92, 2.08, 2.5
    ]
}

# Creazione del DataFrame
df_p2_o2_f = pd.DataFrame(data_p2_o2_f)

# Ricalcola I/E Ratio
df_p2_o2_f['I/E Ratio'] = round((df_p2_o2_f['Inspiration Time (s)'] / df_p2_o2_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p2_o2_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                13                  2.15                 2.31
# 1    2th cycle                15                  2.11                 1.78
# 2    3th cycle                14                  1.98                 2.10
# 3    4th cycle                15                  1.78                 2.08
# 4    5th cycle                14                  1.94                 2.15
# 5    6th cycle                15                  1.78                 2.12
# 6    7th cycle                14                  2.10                 1.94
# 7    8th cycle                15                  1.82                 1.94
# 8    9th cycle                15                  1.80                 2.06
# 9   10th cycle                15                  1.85                 2.07
# 10  11th cycle                15                  1.94                 1.86
# ...

# %% [markdown]
# ## Protocollo 2 - Opzione 3

# %%
# Dati per Protocollo 2 - Opzione 3
data_p2_o3_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle"
    ],
    "RR (breaths/min)": [
        15, 13, 16, 14, 15, 15, 15, 14, 15, 14,
        15, 14, 15,
        13, 14, 15, 15, 15, 15, 14, 15, 15, 14,
        14, 14, 14,
        16, 14, 15, 14, 13, 14, 15, 15, 15, 14,
        14, 15, 15
    ],
    "Inspiration Time (s)": [
        2.02, 2.28, 1.69, 1.87, 1.78, 1.94, 1.77, 1.84, 1.76, 1.9,
        1.91, 1.96, 1.74,
        2.14, 2.06, 1.85, 1.76, 1.73, 1.72, 1.98, 1.77, 1.84, 2.02,
        1.85, 1.91, 1.9,
        1.56, 2.22, 1.87, 1.71, 1.98, 1.9, 1.78, 1.68, 1.87, 1.82,
        1.88, 1.77, 1.81
    ],
    "Expiration Time (s)": [
        1.85, 2.04, 1.96, 2.22, 2.16, 2.06, 2.12, 2.19, 2.08, 2.14,
        2.02, 2.24, 2.09,
        2.22, 1.99, 2.1, 2.24, 2.13, 2.22, 2.04, 2.09, 2.01, 2.02,
        2.16, 2.26, 2.13,
        2.18, 2.0, 2.05, 2.33, 2.48, 2.12, 2.17, 2.21, 1.9, 2.2,
        2.15, 2.13, 2.14
    ]
}

# Creazione del DataFrame
df_p2_o3_f = pd.DataFrame(data_p2_o3_f)

# Ricalcola I/E Ratio
df_p2_o3_f['I/E Ratio'] = round((df_p2_o3_f['Inspiration Time (s)'] / df_p2_o3_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p2_o3_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                15                  2.02                 1.85
# 1    2th cycle                13                  2.28                 2.04
# 2    3th cycle                16                  1.69                 1.96
# 3    4th cycle                14                  1.87                 2.22
# 4    5th cycle                15                  1.78                 2.16
# 5    6th cycle                15                  1.94                 2.06
# 6    7th cycle                15                  1.77                 2.12
# 7    8th cycle                14                  1.84                 2.19
# 8    9th cycle                15                  1.76                 2.08
# 9   10th cycle                14                  1.90                 2.14
# 10  11th cycle                15                  1.91                 2.02
# ...

# %% [markdown]
# ## Protocollo 2 - Opzione 4

# %%
# Dati per Protocollo 2 - Opzione 4
data_p2_o4_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle", "14th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle"
    ],
    "RR (breaths/min)": [
        17, 16, 15, 15, 14, 14, 15, 15, 16, 15,
        15, 15, 14, 15,
        15, 13, 15, 16, 14, 16, 13, 16, 14, 15,
        13, 15, 14,
        10, 17, 16, 15, 15, 15, 15, 14, 15, 17,
        14, 15, 15
    ],
    "Inspiration Time (s)": [
        1.5, 1.94, 2.17, 2.13, 2.06, 2.24, 2.12, 1.9, 1.7, 2.0,
        1.96, 1.86, 2.24, 2.0,
        2.05, 2.22, 2.16, 2.05, 2.17, 2.01, 2.34, 2.14, 2.04, 2.08,
        2.43, 1.98, 2.15,
        3.1, 1.78, 1.88, 2.02, 2.04, 2.06, 2.2, 2.14, 1.99, 1.72,
        2.74, 2.26, 1.94
    ],
    "Expiration Time (s)": [
        1.86, 1.73, 1.73, 1.79, 2.1, 2.05, 1.67, 1.94, 1.96, 1.95,
        1.84, 1.92, 1.98, 1.87,
        1.83, 2.08, 1.74, 1.62, 1.86, 1.68, 2.02, 1.56, 2.22, 1.89,
        1.87, 1.84, 1.96,
        2.68, 1.6, 1.74, 1.93, 1.9, 1.78, 1.76, 2.06, 2.0, 1.66,
        1.52, 1.74, 1.88
    ]
}

# Creazione del DataFrame
df_p2_o4_f = pd.DataFrame(data_p2_o4_f)

# Ricalcola I/E Ratio
df_p2_o4_f['I/E Ratio'] = round((df_p2_o4_f['Inspiration Time (s)'] / df_p2_o4_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p2_o4_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                17                  1.50                 1.86
# 1    2th cycle                16                  1.94                 1.73
# 2    3th cycle                15                  2.17                 1.73
# 3    4th cycle                15                  2.13                 1.79
# 4    5th cycle                14                  2.06                 2.10
# 5    6th cycle                14                  2.24                 2.05
# 6    7th cycle                15                  2.12                 1.67
# 7    8th cycle                15                  1.90                 1.94
# 8    9th cycle                16                  1.70                 1.96
# 9   10th cycle                15                  2.00                 1.95
# 10  11th cycle                15                  1.96                 1.84
# ...

# %% [markdown]
# # Protocol 2 statistical analysis

# %%
# Definisci il target RR
target_rr = 15

# Lista dei dataframe delle varie opzioni
dfs = [df_p2_o1_f, df_p2_o2_f, df_p2_o3_f, df_p2_o4_f]
option_names = ['Option 1', 'Option 2', 'Option 3', 'Option 4']

# Funzione per eseguire l'analisi statistica e generare il grafico per ogni opzione
def analyze_option(df, option_name):
    df['Error'] = df['RR (breaths/min)'] - target_rr

    # Calcolo delle metriche statistiche
    mse = mean_squared_error(df['RR (breaths/min)'], [target_rr] * len(df))
    mae = mean_absolute_error(df['RR (breaths/min)'], [target_rr] * len(df))
    rmse = np.sqrt(mse)
    std_dev = np.std(df['RR (breaths/min)'])

    # Stampa delle metriche
    print(f'{option_name}:')
    print(f'MSE: {mse}')
    print(f'MAE: {mae}')
    print(f'RMSE: {rmse}')
    print(f'Standard Deviation: {std_dev}')
    print('\n')

    # Genera il grafico
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
    plt.axhline(y=target_rr, color='r', linestyle='--', label='Target RR = 12 breaths/min')
    plt.xlabel('Index')
    plt.ylabel('RR (breaths/min)')
    plt.title(f'Respiratory Rate Analysis - {option_name}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Esegui l'analisi per ogni opzione
for df, option_name in zip(dfs, option_names):
    analyze_option(df, option_name)

# Combinazione dei dati per analisi complessiva
df_combined = pd.concat(dfs, ignore_index=True)
df_combined['Error'] = df_combined['RR (breaths/min)'] - target_rr

# Calcolo delle metriche statistiche complessive
mse_total = mean_squared_error(df_combined['RR (breaths/min)'], [target_rr] * len(df_combined))
mae_total = mean_absolute_error(df_combined['RR (breaths/min)'], [target_rr] * len(df_combined))
rmse_total = np.sqrt(mse_total)
std_dev_total = np.std(df_combined['RR (breaths/min)'])

# Stampa delle metriche complessive
print('Overall Analysis:')
print(f'MSE: {mse_total}')
print(f'MAE: {mae_total}')
print(f'RMSE: {rmse_total}')
print(f'Standard Deviation: {std_dev_total}')

# Genera il grafico complessivo
plt.figure(figsize=(12, 6))
plt.plot(df_combined.index, df_combined['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
plt.axhline(y=target_rr, color='r', linestyle='--', label='Target RR = 12 breaths/min')
plt.xlabel('Index')
plt.ylabel('RR (breaths/min)')
plt.title('Respiratory Rate Analysis - Overall')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Option 1:
# MSE: 4.918918918918919
# MAE: 1.2432432432432432
# RMSE: 2.2178635933976913
# Standard Deviation: 2.0643412382625197
# Option 2:
# MSE: 1.0
# MAE: 0.6666666666666666
# RMSE: 1.0
# Standard Deviation: 0.8206518066482897
# Option 3:
# MSE: 0.7435897435897436
# MAE: 0.5897435897435898
# RMSE: 0.8623164985025763
# Standard Deviation: 0.7115095859236723
# Option 4:
# MSE: 1.575
# MAE: 0.775
# RMSE: 1.2549900398011133
# Standard Deviation: 1.2427288521636568
# Overall Analysis:
# MSE: 2.0
# MAE: 0.810126582278481
# RMSE: 1.4142135623730951
# Standard Deviation: 1.3204661405703995

# %% [markdown]
# ## Protocollo 3

# %% [markdown]
# ## Protocollo 3 - Opzione 1

# %%
# Dati per Protocollo 3 - Opzione 1
data_p3_o1_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle", "13th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle"
    ],
    "RR (breaths/min)": [
        11, 12, 11, 11, 14, 16, 12, 19, 11, 14,
        13, 14,
        13, 12, 12, 12, 11, 12, 15, 14, 15, 16,
        15, 14, 14,
        11, 11, 13, 12, 11, 17, 13, 14, 14, 12,
        15, 14
    ],
    "Inspiration Time (s)": [
        2.11, 2.54, 2.54, 2.83, 2.57, 2.34, 2.66, 1.58, 3.12, 2.12,
        1.6, 2.5,
        2.01, 2.42, 2.32, 2.5, 2.44, 2.44, 1.96, 1.91, 1.91, 1.94,
        2.01, 2.17, 2.24,
        2.91, 1.94, 1.93, 2.66, 2.0, 1.31, 1.73, 2.62, 1.51, 1.62,
        2.27, 1.21
    ],
    "Expiration Time (s)": [
        3.02, 2.26, 2.7, 2.19, 1.48, 1.29, 2.18, 1.5, 1.95, 1.93,
        3.0, 1.56,
        2.31, 2.46, 2.35, 2.41, 2.83, 2.4, 1.84, 2.13, 2.08, 1.62,
        1.9, 1.92, 1.78,
        2.12, 3.07, 2.62, 2.24, 3.14, 2.21, 2.57, 1.46, 2.5, 3.15,
        1.7, 3.02
    ]
}

# Creazione del DataFrame
df_p3_o1_f = pd.DataFrame(data_p3_o1_f)

# Ricalcola I/E Ratio
df_p3_o1_f['I/E Ratio'] = round((df_p3_o1_f['Inspiration Time (s)'] / df_p3_o1_f['Expiration Time (s)']), 2)

df_p3_o1_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                11                  2.11                 3.02
# 1    2th cycle                12                  2.54                 2.26
# 2    3th cycle                11                  2.54                 2.70
# 3    4th cycle                11                  2.83                 2.19
# 4    5th cycle                14                  2.57                 1.48
# 5    6th cycle                16                  2.34                 1.29
# 6    7th cycle                12                  2.66                 2.18
# 7    8th cycle                19                  1.58                 1.50
# 8    9th cycle                11                  3.12                 1.95
# 9   10th cycle                14                  2.12                 1.93
# 10  11th cycle                13                  1.60                 3.00
# ...

# %% [markdown]
# ## Protocollo 3 - Opzione 2

# %%
# Dati per Protocollo 3 - Opzione 2
data_p3_o2_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle"
    ],
    "RR (breaths/min)": [
        12, 12, 12, 12, 12, 15, 13, 16, 14, 15,
        15, 13,
        13, 11, 12, 10, 13, 16, 14, 13, 15, 14,
        17, 14,
        12, 12, 12, 11, 12, 19, 13, 13, 13, 15,
        14, 17
    ],
    "Inspiration Time (s)": [
        2.68, 2.22, 2.44, 2.28, 2.31, 1.94, 1.91, 1.92, 2.12, 2.04,
        1.92, 2.04,
        2.58, 3.04, 2.33, 2.25, 2.5, 1.65, 1.92, 2.42, 2.02, 1.76,
        1.76, 1.95,
        1.65, 2.51, 1.78, 2.96, 2.58, 1.31, 2.08, 2.28, 2.28, 1.92,
        1.82, 1.76
    ],
    "Expiration Time (s)": [
        2.03, 2.74, 2.42, 2.48, 2.4, 1.94, 2.54, 1.8, 2.15, 1.96,
        1.98, 2.25,
        1.9, 2.34, 2.5, 3.32, 2.08, 2.06, 2.1, 1.9, 1.76, 2.3,
        1.71, 2.16,
        3.21, 2.22, 3.11, 2.46, 2.28, 1.84, 2.3, 2.02, 2.06, 1.84,
        2.45, 1.72
    ]
}

# Creazione del DataFrame
df_p3_o2_f = pd.DataFrame(data_p3_o2_f)

# Ricalcola I/E Ratio
df_p3_o2_f['I/E Ratio'] = round((df_p3_o2_f['Inspiration Time (s)'] / df_p3_o2_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p3_o2_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                12                  2.68                 2.03
# 1    2th cycle                12                  2.22                 2.74
# 2    3th cycle                12                  2.44                 2.42
# 3    4th cycle                12                  2.28                 2.48
# 4    5th cycle                12                  2.31                 2.40
# 5    6th cycle                15                  1.94                 1.94
# 6    7th cycle                13                  1.91                 2.54
# 7    8th cycle                16                  1.92                 1.80
# 8    9th cycle                14                  2.12                 2.15
# 9   10th cycle                15                  2.04                 1.96
# 10  11th cycle                15                  1.92                 1.98
# ...

# %% [markdown]
# ## Protocollo 3 - Opzione 3

# %%
# Dati per Protocollo 3 - Opzione 2
data_p3_o3_f = {
    "Cycle": [
        "1st cycle", "2nd cycle", "3rd cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1st cycle", "2nd cycle", "3rd cycle", "4th cycle", "5th cycle", "6th cycle",
        "7th cycle", "8th cycle", "9th cycle", "10th cycle", "11th cycle", "12th cycle",
        "1st cycle", "2nd cycle", "3rd cycle", "4th cycle", "5th cycle", "6th cycle",
        "7th cycle", "8th cycle", "9th cycle", "10th cycle", "11th cycle", "12th cycle"
    ],
    "RR (breaths/min)": [
        11, 12, 12, 11, 11, 15, 13, 14, 14, 13,
        15, 13,
        10, 12, 12, 10, 12, 15, 14, 14, 14, 14, 15, 13,
        11, 11, 12, 11, 11, 15, 14, 14, 14, 14, 14, 14
    ],
    "Inspiration Time (s)": [
        2.53, 2.39, 2.0, 2.56, 2.8, 1.88, 2.19, 1.8, 1.93, 1.94,
        1.8, 2.02,
        2.58, 2.5, 2.17, 2.82, 2.13, 1.55, 2.09, 1.9, 1.96, 1.68, 1.84, 2.22,
        2.34, 2.08, 2.14, 2.34, 2.27, 1.93, 2.1, 1.91, 1.92, 1.93, 1.9, 1.98
    ],
    "Expiration Time (s)": [
        2.58, 2.44, 2.84, 2.71, 2.48, 1.92, 2.37, 2.31, 2.13, 2.38,
        2.17, 2.32,
        2.94, 2.38, 2.46, 2.75, 2.84, 2.22, 2.18, 2.31, 2.1, 2.35, 2.06, 2.25,
        2.78, 3.0, 2.62, 2.86, 2.76, 2.06, 2.07, 2.32, 2.23, 2.22, 2.3, 2.08
    ]
}

# Creazione del DataFrame
df_p3_o3_f = pd.DataFrame(data_p3_o3_f)

# Ricalcola I/E Ratio
df_p3_o3_f['I/E Ratio'] = round((df_p3_o3_f['Inspiration Time (s)'] / df_p3_o3_f['Expiration Time (s)']), 2)

# Visualizza il DataFrame corretto
df_p3_o3_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1st cycle                11                  2.53                 2.58
# 1    2nd cycle                12                  2.39                 2.44
# 2    3rd cycle                12                  2.00                 2.84
# 3    4th cycle                11                  2.56                 2.71
# 4    5th cycle                11                  2.80                 2.48
# 5    6th cycle                15                  1.88                 1.92
# 6    7th cycle                13                  2.19                 2.37
# 7    8th cycle                14                  1.80                 2.31
# 8    9th cycle                14                  1.93                 2.13
# 9   10th cycle                13                  1.94                 2.38
# 10  11th cycle                15                  1.80                 2.17
# ...

# %% [markdown]
# ## Protocol 3 - Option 4

# %%
data_p3_o4_f = {
    "Cycle": [
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle", "12th cycle",
        "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
        "11th cycle"
    ],
    "RR (breaths/min)": [
        13, 12, 13, 11, 11, 14, 15, 14, 14, 15,
        14, 15,
        11, 13, 11, 12, 13, 13, 14, 15, 15, 14,
        15, 16,
        11, 14, 12, 13, 12, 15, 13, 14, 15, 15,
        14
    ],
    "Inspiration Time (s)": [
        2.2, 2.32, 2.25, 2.66, 2.9, 2.39, 1.75, 2.09, 2.12, 2.12,
        1.96, 2.01,
        2.33, 2.24, 2.52, 2.54, 2.07, 2.0, 1.94, 1.84, 2.0, 1.84,
        1.92, 1.89,
        2.32, 1.86, 2.31, 2.31, 2.42, 1.84, 2.64, 2.27, 1.89, 1.98,
        2.06
    ],
    "Expiration Time (s)": [
        2.36, 2.37, 2.23, 2.74, 2.28, 1.73, 2.09, 2.03, 2.02, 1.7,
        2.08, 1.94,
        3.0, 2.18, 2.5, 2.13, 2.22, 2.3, 2.29, 1.96, 2.0, 2.17,
        1.89, 1.82,
        2.8, 2.31, 2.52, 2.23, 2.35, 2.08, 1.96, 1.92, 1.98, 1.86,
        2.08
    ]
}

# Create DataFrame
df_p3_o4_f = pd.DataFrame(data_p3_o4_f)

# Recalculate I/E Ratio
df_p3_o4_f['I/E Ratio'] = round((df_p3_o4_f['Inspiration Time (s)'] / df_p3_o4_f['Expiration Time (s)']), 2)
df_p3_o4_f
# Out:
#          Cycle  RR (breaths/min)  Inspiration Time (s)  Expiration Time (s)  \
# 0    1th cycle                13                  2.20                 2.36
# 1    2th cycle                12                  2.32                 2.37
# 2    3th cycle                13                  2.25                 2.23
# 3    4th cycle                11                  2.66                 2.74
# 4    5th cycle                11                  2.90                 2.28
# 5    6th cycle                14                  2.39                 1.73
# 6    7th cycle                15                  1.75                 2.09
# 7    8th cycle                14                  2.09                 2.03
# 8    9th cycle                14                  2.12                 2.02
# 9   10th cycle                15                  2.12                 1.70
# 10  11th cycle                14                  1.96                 2.08
# ...

# %%
# Funzione per ordinare correttamente i cicli
def sort_cycles(df):
    # Estrarre il numero del ciclo
    df['Cycle_Number'] = df['Cycle'].apply(lambda x: int(x.split(' ')[0][:-2]))
    
    # Ordinare per numero di ciclo
    df_sorted = df.sort_values(by=['Cycle_Number']).reset_index(drop=True)
    
    # Rimuovere la colonna ausiliaria
    df_sorted = df_sorted.drop(columns=['Cycle_Number'])
    
    return df_sorted

# %%
df_p3_o1_f_sorted = sort_cycles(df_p3_o1_f)
df_p3_o2_f_sorted = sort_cycles(df_p3_o2_f)
df_p3_o3_f_sorted = sort_cycles(df_p3_o3_f)
df_p3_o4_f_sorted = sort_cycles(df_p3_o4_f)

df_all = pd.concat([df_p3_o1_f_sorted, df_p3_o2_f_sorted, df_p3_o3_f_sorted, df_p3_o4_f_sorted])
df_all_sorted = sort_cycles(df_all)

# %% [markdown]
# # Protocol 3 statistical analysis

# %%
# Definisci il target RR per i due segmenti
target_rr_1 = 12
target_rr_2 = 15

# Lista dei dataframe ordinati delle varie opzioni
dfs_sorted = [df_p3_o1_f_sorted, df_p3_o2_f_sorted, df_p3_o3_f_sorted, df_p3_o4_f_sorted]
option_names = ['Option 1', 'Option 2', 'Option 3', 'Option 4']

# Funzione per eseguire l'analisi statistica e generare il grafico per ogni opzione
def analyze_option(df, option_name):
    df['Target RR'] = target_rr_1
    df.loc[15:, 'Target RR'] = target_rr_2
    df['Error'] = df['RR (breaths/min)'] - df['Target RR']

    # Calcolo delle metriche statistiche per i due segmenti
    mse_1 = mean_squared_error(df['RR (breaths/min)'][:15], [target_rr_1] * 15)
    mae_1 = mean_absolute_error(df['RR (breaths/min)'][:15], [target_rr_1] * 15)
    rmse_1 = np.sqrt(mse_1)
    std_dev_1 = np.std(df['RR (breaths/min)'][:15])

    mse_2 = mean_squared_error(df['RR (breaths/min)'][15:], [target_rr_2] * len(df['RR (breaths/min)'][15:]))
    mae_2 = mean_absolute_error(df['RR (breaths/min)'][15:], [target_rr_2] * len(df['RR (breaths/min)'][15:]))
    rmse_2 = np.sqrt(mse_2)
    std_dev_2 = np.std(df['RR (breaths/min)'][15:])

    # Stampa delle metriche
    print(f'{option_name} (Target 12):')
    print(f'MSE: {mse_1}')
    print(f'MAE: {mae_1}')
    print(f'RMSE: {rmse_1}')
    print(f'Standard Deviation: {std_dev_1}')
    print('\n')
    
    print(f'{option_name} (Target 15):')
    print(f'MSE: {mse_2}')
    print(f'MAE: {mae_2}')
    print(f'RMSE: {rmse_2}')
    print(f'Standard Deviation: {std_dev_2}')
    print('\n')

    # Genera il grafico
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
    plt.axhline(y=target_rr_1, xmin=0, xmax=15/len(df), color='r', linestyle='--', label='Target RR = 12 breaths/min')
    plt.axhline(y=target_rr_2, xmin=15/len(df), xmax=1, color='g', linestyle='--', label='Target RR = 15 breaths/min')
    plt.xlabel('Index')
    plt.ylabel('RR (breaths/min)')
    plt.title(f'Respiratory Rate Analysis - {option_name}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Esegui l'analisi per ogni opzione
for df, option_name in zip(dfs_sorted, option_names):
    analyze_option(df, option_name)

# Combinazione dei dati per analisi complessiva
df_combined = pd.concat(dfs_sorted, ignore_index=True)
df_all_sorted['Target RR'] = target_rr_1
df_all_sorted.loc[60:, 'Target RR'] = target_rr_2
df_all_sorted['Error'] = df_all_sorted['RR (breaths/min)'] - df_all_sorted['Target RR']

# Calcolo delle metriche statistiche complessive per i due segmenti
mse_total_1 = mean_squared_error(df_all_sorted['RR (breaths/min)'][:60], [target_rr_1] * 60)
mae_total_1 = mean_absolute_error(df_all_sorted['RR (breaths/min)'][:60], [target_rr_1] * 60)
rmse_total_1 = np.sqrt(mse_total_1)
std_dev_total_1 = np.std(df_all_sorted['RR (breaths/min)'][:60])

mse_total_2 = mean_squared_error(df_all_sorted['RR (breaths/min)'][60:], [target_rr_2] * len(df_all_sorted['RR (breaths/min)'][60:]))
mae_total_2 = mean_absolute_error(df_all_sorted['RR (breaths/min)'][60:], [target_rr_2] * len(df_all_sorted['RR (breaths/min)'][60:]))
rmse_total_2 = np.sqrt(mse_total_2)
std_dev_total_2 = np.std(df_all_sorted['RR (breaths/min)'][60:])

# Stampa delle metriche complessive
print('Overall Analysis (Target 12):')
print(f'MSE: {mse_total_1}')
print(f'MAE: {mae_total_1}')
print(f'RMSE: {rmse_total_1}')
print(f'Standard Deviation: {std_dev_total_1}')
print('\n')

print('Overall Analysis (Target 15):')
print(f'MSE: {mse_total_2}')
print(f'MAE: {mae_total_2}')
print(f'RMSE: {rmse_total_2}')
print(f'Standard Deviation: {std_dev_total_2}')

# Genera il grafico complessivo
plt.figure(figsize=(12, 6))
plt.plot(df_all_sorted.index, df_all_sorted['RR (breaths/min)'], marker='o', linestyle='-', color='b', label='RR (breaths/min)')
plt.axhline(y=target_rr_1, xmin=0, xmax=60/len(df_all_sorted), color='r', linestyle='--', label='Target RR = 12 breaths/min')
plt.axhline(y=target_rr_2, xmin=60/len(df_all_sorted), xmax=1, color='g', linestyle='--', label='Target RR = 15 breaths/min')
plt.xlabel('Index')
plt.ylabel('RR (breaths/min)')
plt.title('Respiratory Rate Analysis - Overall')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Option 1 (Target 12):
# MSE: 0.8666666666666667
# MAE: 0.7333333333333333
# RMSE: 0.9309493362512627
# Standard Deviation: 0.9092121131323905
#
#
# Option 1 (Target 15):
# MSE: 3.6818181818181817
# MAE: 1.5
# RMSE: 1.9188064472004938
# Standard Deviation: 1.7563344623965145
# Option 2 (Target 12):
# MSE: 0.5333333333333333
# MAE: 0.4
# RMSE: 0.7302967433402214
# Standard Deviation: 0.7180219742846006
#
#
# Option 2 (Target 15):
# MSE: 2.619047619047619
# MAE: 1.2857142857142858
# RMSE: 1.618347187425374
# Standard Deviation: 1.5836465855538944
# Option 3 (Target 12):
# MSE: 1.0
# MAE: 0.7333333333333333
# RMSE: 1.0
# Standard Deviation: 0.6798692684790381
#
#
# Option 3 (Target 15):
# MSE: 1.3333333333333333
# MAE: 0.9523809523809523
# RMSE: 1.1547005383792515
# Standard Deviation: 0.6529194857524803
# Option 4 (Target 12):
# MSE: 0.9333333333333333
# MAE: 0.8
# RMSE: 0.9660917830792959
# Standard Deviation: 0.956846672960488
#
#
# Option 4 (Target 15):
# MSE: 0.85
# MAE: 0.65
# ...

# %% [markdown]
# # Protocol 4

# %% [markdown]
# ## Protocol 4 - Option 1

# %%
# data_p4_o1_f = {
#     "Cycle": [
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle", "17th cycle", "18th cycle", "19th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle"
#     ],
#     "RR (breaths/min)": [
#         22, 23, 25, 18, 19, 20, 20, 19, 20, 19,
#         20, 20, 21, 19, 18, 17, 17, 18, 20,
#         10, 12, 14, 14, 14, 14, 16, 14, 17, 14,
#         14, 22,
#         12, 14, 13, 15, 14, 14, 16, 11, 14, 13,
#         14, 13, 14
#     ],
#     "Inspiration Time (s)": [
#         1.66, 1.22, 1.15, 1.5, 1.4, 1.58, 1.5, 1.6, 1.41, 1.35,
#         1.52, 1.3, 1.7, 1.4, 1.54, 1.68, 1.58, 1.76, 1.31,
#         3.62, 1.61, 1.76, 2.01, 1.94, 1.44, 1.68, 1.43, 1.62, 2.62,
#         2.7, 1.4,
#         1.5, 1.62, 2.73, 1.74, 1.51, 1.78, 1.66, 2.14, 1.6, 1.44,
#         1.74, 1.59, 2.08
#     ],
#     "Expiration Time (s)": [
#         1.07, 1.29, 1.22, 1.72, 1.67, 1.35, 1.46, 1.44, 1.52, 1.66,
#         1.43, 1.7, 1.14, 1.74, 1.72, 1.68, 1.8, 1.54, 1.66,
#         2.05, 3.24, 2.44, 2.0, 2.28, 2.75, 1.86, 2.84, 1.8, 1.41,
#         1.58, 1.22,
#         3.14, 2.46, 1.86, 2.07, 2.73, 2.25, 2.04, 3.26, 2.46, 3.03,
#         2.38, 2.72, 2.14
#     ]
# }

# # Create DataFrame
# df_p4_o1_f = pd.DataFrame(data_p4_o1_f)

# # Recalculate I/E Ratio
# df_p4_o1_f['I/E Ratio'] = round((df_p4_o1_f['Inspiration Time (s)'] / df_p4_o1_f['Expiration Time (s)']), 2)
# df_p4_o1_f

# %% [markdown]
# ## Protocol 4 - Option 2

# %%
# data_p4_o2_f = {
#     "Cycle": [
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle"
#     ],
#     "RR (breaths/min)": [
#         15, 25, 18, 20, 19, 10, 17, 13, 12, 18,
#         15, 12, 13,
#         19, 13, 26, 15, 23, 16, 16, 14, 22, 17,
#         13, 15, 14, 22, 19, 18,
#         9, 19, 15, 24, 10, 20, 18, 18, 14, 18,
#         15, 18, 18, 20, 19
#     ],
#     "Inspiration Time (s)": [
#         2.13, 1.44, 2.19, 1.48, 1.86, 3.36, 1.18, 2.62, 1.55, 1.82,
#         2.06, 3.0, 2.24,
#         1.42, 3.36, 1.12, 1.82, 1.4, 2.05, 1.3, 2.0, 1.25, 1.27,
#         2.84, 2.1, 2.22, 1.6, 1.3, 1.65,
#         4.62, 1.92, 1.58, 1.36, 3.42, 1.54, 1.36, 1.72, 1.6, 1.62,
#         1.25, 1.79, 1.6, 1.21, 1.46
#     ],
#     "Expiration Time (s)": [
#         1.67, 0.92, 0.99, 1.48, 1.23, 2.38, 2.24, 1.95, 3.4, 1.51,
#         1.78, 1.86, 2.16,
#         1.63, 1.08, 1.19, 2.03, 1.2, 1.68, 2.38, 2.12, 1.44, 2.17,
#         1.62, 1.7, 1.95, 1.11, 1.82, 1.66,
#         1.68, 1.23, 2.26, 1.13, 2.06, 1.43, 1.9, 1.49, 2.42, 1.65,
#         2.58, 1.44, 1.72, 1.68, 1.68
#     ]
# }

# # Create DataFrame
# df_p4_o2_f = pd.DataFrame(data_p4_o2_f)

# # Recalculate I/E Ratio
# df_p4_o2_f['I/E Ratio'] = round((df_p4_o2_f['Inspiration Time (s)'] / df_p4_o2_f['Expiration Time (s)']), 2)
# df_p4_o2_f

# %% [markdown]
# ## Protocollo 4 - Opzione 3

# %%
# data_p4_o3_f = {
#     "Cycle": [
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle", "17th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle", "17th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle", "17th cycle"
#     ],
#     "RR (breaths/min)": [
#         10, 14, 21, 18, 19, 19, 18, 19, 23, 17,
#         24, 16, 19, 22, 15, 16, 17,
#         18, 20, 18, 17, 18, 15, 17, 18, 16, 19,
#         20, 18, 16, 16, 18, 17, 18,
#         16, 17, 17, 19, 20, 21, 18, 19, 17, 17,
#         18, 17, 18, 22, 20, 19, 21
#     ],
#     "Inspiration Time (s)": [
#         1.55, 2.47, 1.38, 1.62, 1.48, 1.48, 1.69, 1.5, 1.2, 1.69,
#         1.18, 1.62, 1.68, 1.08, 2.0, 1.66, 1.68,
#         1.58, 1.5, 1.52, 1.68, 1.58, 2.0, 1.66, 1.64, 1.79, 1.52,
#         1.4, 1.42, 1.86, 1.74, 1.6, 1.66, 1.64,
#         1.75, 1.62, 1.68, 1.52, 1.4, 1.42, 1.46, 1.76, 1.41, 1.72,
#         1.55, 1.62, 1.7, 1.28, 1.32, 1.56, 1.52
#     ],
#     "Expiration Time (s)": [
#         3.92, 1.64, 1.46, 1.64, 1.66, 1.58, 1.56, 1.56, 1.3, 1.73,
#         1.31, 1.93, 1.36, 1.61, 1.82, 1.94, 1.74,
#         1.64, 1.5, 1.71, 1.7, 1.72, 1.88, 1.74, 1.56, 1.92, 1.58,
#         1.57, 1.8, 1.72, 1.92, 1.74, 1.72, 1.68,
#         1.82, 1.78, 1.7, 1.49, 1.53, 1.4, 1.84, 1.28, 1.96, 1.74,
#         1.72, 1.79, 1.6, 1.44, 1.64, 1.56, 1.24
#     ]
# }

# # Create DataFrame
# df_p4_o3_f = pd.DataFrame(data_p4_o3_f)

# # Recalculate I/E Ratio
# df_p4_o3_f['I/E Ratio'] = round((df_p4_o3_f['Inspiration Time (s)'] / df_p4_o3_f['Expiration Time (s)']), 2)
# df_p4_o3_f

# %% [markdown]
# ## Protocol 4 - Opzione 4

# %%
# data_p4_o4_f = {
#     "Cycle": [
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle", "16th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle",
#         "1th cycle", "2th cycle", "3th cycle", "4th cycle", "5th cycle", "6th cycle", "7th cycle", "8th cycle", "9th cycle", "10th cycle",
#         "11th cycle", "12th cycle", "13th cycle", "14th cycle", "15th cycle"
#     ],
#     "RR (breaths/min)": [
#         19, 15, 16, 15, 19, 15, 22, 16, 21, 17,
#         19, 18, 18, 16, 15, 16,
#         15, 12, 16, 14, 15, 16, 15, 16, 17, 16,
#         17, 15, 14, 20,
#         20, 19, 14, 17, 19, 18, 18, 16, 8, 16,
#         19, 19, 21, 17, 18
#     ],
#     "Inspiration Time (s)": [
#         2.2, 1.34, 2.13, 2.64, 1.61, 1.73, 1.44, 2.11, 1.32, 1.64,
#         1.48, 1.78, 1.36, 1.82, 1.86, 2.04,
#         1.44, 1.98, 2.02, 2.45, 2.0, 1.76, 2.04, 1.82, 1.71, 1.94,
#         1.18, 1.34, 1.97, 1.38,
#         1.34, 1.38, 1.26, 1.92, 1.18, 1.86, 1.34, 1.68, 1.8, 1.72,
#         1.51, 1.66, 1.53, 1.95, 1.74
#     ],
#     "Expiration Time (s)": [
#         0.96, 2.46, 1.6, 1.14, 1.46, 2.11, 1.22, 1.5, 1.54, 1.8,
#         1.64, 1.39, 1.84, 1.75, 2.08, 1.62,
#         2.5, 2.7, 1.53, 1.83, 1.92, 1.83, 1.75, 1.82, 1.72, 1.71,
#         2.34, 2.53, 2.12, 1.6,
#         1.66, 1.65, 2.8, 1.5, 1.98, 1.32, 1.97, 1.88, 5.04, 2.03,
#         1.5, 1.46, 1.22, 1.42, 1.48
#     ]
# }

# # Create DataFrame
# df_p4_o4_f = pd.DataFrame(data_p4_o4_f)

# # Recalculate I/E Ratio
# df_p4_o4_f['I/E Ratio'] = round((df_p4_o4_f['Inspiration Time (s)'] / df_p4_o4_f['Expiration Time (s)']), 2)
# df_p4_o4_f
